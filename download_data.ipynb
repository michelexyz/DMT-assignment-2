# %% [markdown]
# ### Downloading the data (optional)

# %%
# !kaggle competitions download -c dmt-2024-2nd-assignment -p data
# Out:
# ...
#  99%|███████████████████████████████████████▊| 270M/272M [00:11<00:00, 24.5MB/s]
# 100%|████████████████████████████████████████| 272M/272M [00:11<00:00, 25.7MB/s]

# %%
# unzip the data
# !unzip data/dmt-2024-2nd-assignment.zip -d data
# Out:
# Archive:  data/dmt-2024-2nd-assignment.zip
#   inflating: data/submission_sample.csv
#   inflating: data/test_set_VU_DM.csv
#   inflating: data/training_set_VU_DM.csv
